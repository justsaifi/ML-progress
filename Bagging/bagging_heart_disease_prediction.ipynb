# %%
import pandas as pd
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df['Sex'].unique()
df['RestingECG'].unique()
df['ChestPainType'].unique()
df['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Sex']=le.fit_transform(df['Sex'])
df['ExerciseAngina']=le.fit_transform(df['ExerciseAngina'])

# %%
df=pd.get_dummies(df,columns=["ChestPainType", "RestingECG", "ST_Slope"],drop_first=True)

# %%
df
# Out:
#      Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0     40    1        140          289          0    172               0
# 1     49    0        160          180          0    156               0
# 2     37    1        130          283          0     98               0
# 3     48    0        138          214          0    108               1
# 4     54    1        150          195          0    122               0
# ..   ...  ...        ...          ...        ...    ...             ...
# 913   45    1        110          264          0    132               0
# 914   68    1        144          193          1    141               0
# 915   57    1        130          131          0    115               1
# 916   57    0        130          236          0    174               0
# 917   38    1        138          175          0    173               0
#
#      Oldpeak  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0        0.0             0               True              False
# 1        1.0             1              False               True
# 2        0.0             0               True              False
# 3        1.5             1              False              False
# 4        0.0             0              False               True
# ..       ...           ...                ...                ...
# 913      1.2             1              False              False
# 914      3.4             1              False              False
# 915      1.2             1              False              False
# 916      0.0             1               True              False
# 917      0.0             0              False               True
#
#      ChestPainType_TA  RestingECG_Normal  RestingECG_ST  ST_Slope_Flat  \
# 0               False               True          False          False
# 1               False               True          False           True
# 2               False              False           True          False
# 3               False               True          False           True
# 4               False               True          False          False
# ..                ...                ...            ...            ...
# 913              True               True          False           True
# 914             False               True          False           True
# 915             False               True          False           True
# 916             False              False          False           True
# 917             False               True          False          False
#
#      ST_Slope_Up
# 0           True
# 1          False
# 2           True
# 3          False
# 4           True
# ..           ...
# 913        False
# 914        False
# 915        False
# 916        False
# 917         True
#
# [918 rows x 16 columns]

# %%
df.describe()
# Out:
#               Age         Sex   RestingBP  Cholesterol   FastingBS  \
# count  918.000000  918.000000  918.000000   918.000000  918.000000
# mean    53.510893    0.789760  132.396514   198.799564    0.233115
# std      9.432617    0.407701   18.514154   109.384145    0.423046
# min     28.000000    0.000000    0.000000     0.000000    0.000000
# 25%     47.000000    1.000000  120.000000   173.250000    0.000000
# 50%     54.000000    1.000000  130.000000   223.000000    0.000000
# 75%     60.000000    1.000000  140.000000   267.000000    0.000000
# max     77.000000    1.000000  200.000000   603.000000    1.000000
#
#             MaxHR  ExerciseAngina     Oldpeak  HeartDisease
# count  918.000000      918.000000  918.000000    918.000000
# mean   136.809368        0.404139    0.887364      0.553377
# std     25.460334        0.490992    1.066570      0.497414
# min     60.000000        0.000000   -2.600000      0.000000
# 25%    120.000000        0.000000    0.000000      0.000000
# 50%    138.000000        0.000000    0.600000      1.000000
# 75%    156.000000        1.000000    1.500000      1.000000
# max    202.000000        1.000000    6.200000      1.000000

# %%
x = df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
dt=DecisionTreeClassifier()
score = cross_val_score(DecisionTreeClassifier(),x,y,cv=5)

# %%
score
# Out:
# array([0.74456522, 0.71195652, 0.7826087 , 0.66666667, 0.67759563])

# %%
score.mean()
# Out:
# np.float64(0.7166785459729151)

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
    estimator=dt,
    n_estimators=10,
    max_samples=0.8,
    oob_score=True,
    random_state=0
)

# %%
bag_model.fit(X_train,y_train)
bag_model.oob_score_
# Out:
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# 0.8038147138964578

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
    estimator=dt,
    n_estimators=10,
    max_samples=0.8,
    oob_score=True,
    random_state=0
)
scores = cross_val_score(bag_model,x,y,cv=5)
# Out:
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:917: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\SYED SAIF ALI SHAH\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_bagging.py:923: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]

# %%
scores
# Out:
# array([0.85869565, 0.81521739, 0.82608696, 0.7704918 , 0.71584699])

# %%
scores.mean()
# Out:
# np.float64(0.7972677595628416)

# %%
print(f"Cross Validation Accuracy: {scores.mean():.2%}")
# Out:
# Cross Validation Accuracy: 79.73%
